# %%
import os
import sys
import cv2
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
cam = cv2.VideoCapture("../data/proc/hello-training-data/output4.avi")
ret, frame = cam.read()

# %%
img = frame.copy()

# %%
for x in range(100,200):
    for y in range (300,400):
        img[x,y] = np.array([255,0,0] ,dtype=np.uint8)

# %%
print type(img)
plt.imshow(img)
# Out:
# <type 'numpy.ndarray'>

# %%
import cv2
import numpy as np
img = np.random.randint(100, size=(100, 100,3))
gen = np.array(img ,dtype=np.uint8)
plt.imshow(gen)

# %%
# img = np.array(0 ,size=(480,640,3))  
img = np.zeros(shape=(480,640,3))
# for x in range(img.shape[0]):
#     for y in range(img.shape[1]):
#         img[x,y] = np.array([0,0,0], dtype = np.uint8)
img = np.array(img, dtype=np.uint8)
print img.shape
print img[0,0]
print type(img)


for x in range(100,200):
    for y in range (300,400):
        img[x,y] = np.array([255,0,0] ,dtype=np.uint8)
        
plt.imshow(img)
# Out:
# (480, 640, 3)
# [0 0 0]
# <type 'numpy.ndarray'>

# %%
dummy_img = np.zeros(img.shape)

# %%
dummy_img.shape
# Out:
# (480, 640, 3)

# %%
plt.imshow(dummy_img)
