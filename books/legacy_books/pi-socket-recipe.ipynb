# %%
import io, time
import socket
import struct
from PIL import Image
import numpy as np
import cv2
from StringIO import StringIO

# %%
def convert_image(img_obj):
    return np.array(img_obj.convert('RGB'))

def convert_image2(r):
    return Image.open(StringIO(r.content))

# %%
# Start a socket listening for connections on 0.0.0.0:8000 (0.0.0.0 means
# all interfaces)
server_socket = socket.socket()
server_socket.bind(('0.0.0.0', 8000))
server_socket.listen(0)
i = 0
fps_mod = 8
start_time = 0
# Accept a single connection and make a file-like object out of it
connection = server_socket.accept()[0].makefile('rb')

# %%
connection.close()
server_socket.close()

# %%
try:
    while True:
        # Read the length of the image as a 32-bit unsigned int. If the
        # length is zero, quit the loop
        try:
            image_len = struct.unpack('<L', connection.read(struct.calcsize('<L')))[0]
            if not image_len:
                break
        except:
            print 'nah'
        # Construct a stream to hold the image data and read the image
        # data from the connection
        image_stream = io.BytesIO()
        image_stream.write(connection.read(image_len))
        # Rewind the stream, open it as an image with PIL and do some
        # processing on it
        image_stream.seek(0)
        if True:
            image = Image.open(image_stream)
            print('Image is %dx%d' % image.size)
            image.verify()
            
            break
except:
    print 'nah'
# Out:
# Image is 640x480

# %%
img2 = Image.open(image_stream)

# %%
type(img2)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
img3 = cv2.imread(img2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-c64c9c6e9f8f> in <module>()
# ----> 1 img3 = cv2.imread(img2)
#
# TypeError: expected string or Unicode object, JpegImageFile found

# %%
img3 = cv2.imread(img2.tobytes())

# %%
cv2.imshow(img3,'hey')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-ace7c9865a26> in <module>()
# ----> 1 cv2.imshow(img3,'hey')
#
# TypeError: mat is not a numpy array, neither a scalar

# %%
type(img3)
# Out:
# NoneType

# %%
out = img2.tobytes()

# %%
type(out)
# Out:
# str

# %%
len(out)
# Out:
# 921600

# %%
out[:30]
# Out:
# "D1 D1 C2 B1\x1fE3\x1dD2\x1aE3\x1bH5$J4'H2%"

# %%
from matplotlib import pyplot as plt

# %%
# %matplotlib inline

# %%
def convert_image(img_obj):
    return np.array(img_obj.convert('RGB'))

def convert_image2(r):
    return Image.open(StringIO(r.content))

# %%
cv2.imread()

# %%
out2 = cv2.imdecode(out)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-f7ecc68468ff> in <module>()
# ----> 1 out2 = cv2.imdecode(out)
#
# TypeError: Required argument 'flags' (pos 2) not found

# %%
type(img2)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
np_img = np.array(img2)

# %%
plt.imshow(np_img)

# %%
np_img.shape
# Out:
# (480, 640, 3)

# %%
img2
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480 at 0x71F3890>

# %%
cv2.imshow(np_img,'out')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-c04cf70dd39b> in <module>()
# ----> 1 cv2.imshow(np_img,'out')
#
# TypeError: expected string or Unicode object, numpy.ndarray found

# %%
np_img.shape
# Out:
# (480, 640, 3)

# %%
type(np_img)
# Out:
# numpy.ndarray

# %%
m1 = cv2.imread('C:\\Users\\wsutt\\Desktop\\files\\ppd\\ppd\\scratch\\murder1.jpg')

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\wsutt\\Desktop\\files\\ppd\\ppd\\scratch'

# %%
out5 = np.array(out)

# %%
cv = convert_image(out)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-49-932e59efaa0b> in <module>()
# ----> 1 cv = convert_image(out)
#
# <ipython-input-48-0e39aedb453d> in convert_image(img_obj)
#       1 def convert_image(img_obj):
# ----> 2     return np.array(img_obj.convert('RGB'))
#       3
#       4 def convert_image2(r):
#       5     return Image.open(StringIO(r.content))
#
# AttributeError: 'str' object has no attribute 'convert'

# %%
plt.imshow(img3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-93a2634a758f> in <module>()
# ----> 1 plt.imshow(img3)
#
# c:\python27\lib\site-packages\matplotlib\pyplot.pyc in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, hold, data, **kwargs)
#    3155                         filternorm=filternorm, filterrad=filterrad,
#    3156                         imlim=imlim, resample=resample, url=url, data=data,
# -> 3157                         **kwargs)
#    3158     finally:
#    3159         ax._hold = washold
#
# c:\python27\lib\site-packages\matplotlib\__init__.pyc in inner(ax, *args, **kwargs)
#    1896                     warnings.warn(msg % (label_namer, func.__name__),
#    1897                                   RuntimeWarning, stacklevel=2)
# ...

# %%
img2
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480 at 0x445B1D0>

# %%
def convert_image3(inp):
    return cv2.imdecode(np.asarray(bytearray(inp)), 1)

# %%
image.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-9d685dbc656f> in <module>()
# ----> 1 image.show()
#
# c:\python27\lib\site-packages\PIL\Image.pyc in show(self, title, command)
#    1938         """
#    1939
# -> 1940         _show(self, title=title, command=command)
#    1941
#    1942     def split(self):
#
# c:\python27\lib\site-packages\PIL\Image.pyc in _show(image, **options)
#    2726 def _show(image, **options):
#    2727     # override me, as necessary
# -> 2728     _showxv(image, **options)
#    2729
#    2730
#
# c:\python27\lib\site-packages\PIL\Image.pyc in _showxv(image, title, **options)
#    2731 def _showxv(image, title=None, **options):
#    2732     from . import ImageShow
# -> 2733     ImageShow.show(image, title, **options)
#    2734
#    2735
#
# c:\python27\lib\site-packages\PIL\ImageShow.pyc in show(image, title, **options)
# ...

# %%
type(q)
# Out:
# NoneType

# %%
img = convert_image3(image)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-b1d7d5340a15> in <module>()
# ----> 1 img = convert_image3(image)
#
# <ipython-input-11-b282776cfaa9> in convert_image3(inp)
#       1 def convert_image3(inp):
# ----> 2     return cv2.imdecode(np.asarray(bytearray(inp)), 1)
#
# TypeError: 'JpegImageFile' object is not iterable

# %%
len(image)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-62f8ce528877> in <module>()
# ----> 1 len(image)
#
# TypeError: object of type 'JpegImageFile' has no len()

# %%
img = image.frombytes()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-50bd9414db78> in <module>()
# ----> 1 img = image.frombytes()
#
# TypeError: frombytes() takes at least 2 arguments (1 given)

# %%
out = convert_image(image)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-c23f009647e0> in <module>()
# ----> 1 out = convert_image(image)
#
# <ipython-input-2-0e39aedb453d> in convert_image(img_obj)
#       1 def convert_image(img_obj):
# ----> 2     return np.array(img_obj.convert('RGB'))
#       3
#       4 def convert_image2(r):
#       5     return Image.open(StringIO(r.content))
#
# c:\python27\lib\site-packages\PIL\Image.pyc in convert(self, mode, matrix, dither, palette, colors)
#     858                 return self.copy()
#     859
# --> 860         self.load()
#     861
#     862         if matrix:
#
# c:\python27\lib\site-packages\PIL\ImageFile.pyc in load(self)
#     149             use_mmap = False
#     150         except AttributeError:
# --> 151             read = self.fp.read
#     152
#     153         try:
#
# AttributeError: 'NoneType' object has no attribute 'read'
